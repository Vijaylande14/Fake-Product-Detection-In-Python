# %% [markdown]
# ## Data Preprocessing

# %%
#!pip install wordcloud
# !pip install textblob
# Out:
# Collecting textblob
#   Obtaining dependency information for textblob from https://files.pythonhosted.org/packages/02/07/5fd2945356dd839974d3a25de8a142dc37293c21315729a41e775b5f3569/textblob-0.18.0.post0-py3-none-any.whl.metadata
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nltk>=3.8 in c:\users\nikhi\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\nikhi\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\nikhi\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nikhi\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\nikhi\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\nikhi\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/626.3 kB 960.0 kB/s eta 0:00:01
#    --------- ------------------------------ 143.4/626.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 450.6/626.3 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  624.6/626.3 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 626.3/626.3 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.18.0.post0

# %%
#LIBRARIES 
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
from textblob import TextBlob
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import  PorterStemmer 
import string
import re
import warnings
warnings.simplefilter("ignore")

# %%
#Loading our dataset 
df = pd.read_csv("Data/updated_data.csv",encoding="latin1") #due to special charas should be encoded as latin 1
#REMOVE MAX
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    Unnamed: 0 review_date  review_rating  \
# 0           0    1/1/2019              5
# 1           1    1/2/2019              5
# 2           2    1/2/2019              4
# 3           3    1/2/2019              5
# 4           4    1/2/2019              5
#
#                                         review_title  \
# 0                            Dove MenÂs + Deodorant
# 1                         Great for a marmite lover!
# 2                                       Vitamin B12.
# 3  A Very Handy Flavour Top - Up to Keep In The C...
# 4                                         Very handy
#
#                                          review_text  verified_purchase
# 0  As you get older, you know what you like and w...               True
# 1  Three gigantic marmite jars that will last pro...               True
# 2                                          Excellent               True
# 3         A great flavour top - up for slow cooking.               True
# 4                          Does what is says it does              False

# %%
#DROPPING UNWANTED COLUMN
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
#Data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2501 entries, 0 to 2500
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   review_date        2501 non-null   object
#  1   review_rating      2501 non-null   int64
#  2   review_title       2403 non-null   object
#  3   review_text        2501 non-null   object
#  4   verified_purchase  2501 non-null   bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 80.7+ KB

# %% [markdown]
# In our first EDA with the entire dataset, the duplicates within the reviews were not detected, which could be due to the other columns having slightly different values. Since we have removed the other columns and all we have left are the review_centric values, we need to double check on whether there are duplicated reviews within the dataset, which we can remove accordingly to remove potential bias.
#
# ### Removing Duplicates
# Initially, in the first data exploration in the old cvs file, we have tried finding out the duplicates within this dataset. However, initially it did not yield any results. To double check on whether this dataset really has no duplicates, the selected columns were added to aid see if there are actually any duplicates within this dataset.

# %%
#CHECK TOTAL DUPLICATE OCCURENCES
dup = df.duplicated().sum()
print("Number of duplicates in dataset: ", dup)
# Out:
# Number of duplicates in dataset:  783

# %%
df = df.drop_duplicates().reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   review_date        1718 non-null   object
#  1   review_rating      1718 non-null   int64
#  2   review_title       1652 non-null   object
#  3   review_text        1718 non-null   object
#  4   verified_purchase  1718 non-null   bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 55.5+ KB

# %%
#Re-checking for null values
df.isnull().sum()
# Out:
# review_date           0
# review_rating         0
# review_title         66
# review_text           0
# verified_purchase     0
# dtype: int64

# %%
#Drop review_title
df.drop(["review_title","review_date"], axis=1, 
        inplace=True)
df.head()
# Out:
#    review_rating                                        review_text  \
# 0              5  As you get older, you know what you like and w...
# 1              5  Three gigantic marmite jars that will last pro...
# 2              4                                          Excellent
# 3              5         A great flavour top - up for slow cooking.
# 4              5                          Does what is says it does
#
#    verified_purchase
# 0               True
# 1               True
# 2               True
# 3               True
# 4              False

# %% [markdown]
# ## EDA ON THE REVIEW TEXT
#
# We have conducted an in-depth review surrounding the background of the Amazon dataset, and this time the review_text itself is going to be taken a further look. To aid in our pre-processing, certain columns will be added to understand certain instances the sentences have. Those include the counts of:
#
# 1. Word
# 2. Characters (with spaces)
# 3. Stopwords
# 4. Punctuations
# 5. Uppercase characters
#
# After the columns are added, necessary summary statistics will be conducted to get an idea on how the pre-processing will take place.

# %%
#WORD COUNT
df['total words'] = df['review_text'].apply(lambda i: len(str(i).split(" ")))

#CHARACTER COUNT
df['total characters'] = df['review_text'].str.len() #spaces are included

#STOPWORDS COUNT
sw = set(stopwords.words('english'))
df['total stopwords'] = df['review_text'].str.split().apply(lambda i: len(set(i) & sw))

#PUNCTUATION AND SPECIAL CHARA COUNT
count_p = lambda p1,p2: sum([1 for i in p1 if i in p2])
df['total punctuations'] = df.review_text.apply(lambda p: count_p(p, string.punctuation))

#UPPERCASE CHARA COUNT
df['total uppercases'] = df['review_text'].str.findall(r'[A-Z]').str.len() #findall - finds all

# %%
df.head() #UPDATED
# Out:
#    review_rating                                        review_text  \
# 0              5  As you get older, you know what you like and w...
# 1              5  Three gigantic marmite jars that will last pro...
# 2              4                                          Excellent
# 3              5         A great flavour top - up for slow cooking.
# 4              5                          Does what is says it does
#
#    verified_purchase  total words  total characters  total stopwords  \
# 0               True           39               202               10
# 1               True           30               175                7
# 2               True            1                 9                0
# 3               True            9                42                2
# 4              False            6                25                4
#
#    total punctuations  total uppercases
# 0                   7                 5
# 1                   6                 4
# 2                   0                 1
# 3                   2                 1
# 4                   0                 1

# %%
#Summary statistics 
df.describe()
# Out:
#        review_rating  total words  total characters  total stopwords  \
# count    1718.000000  1718.000000       1718.000000      1718.000000
# mean        4.441793    33.198487        177.890570         9.257276
# std         1.123083    35.251879        189.818467         8.537092
# min         1.000000     1.000000          2.000000         0.000000
# 25%         4.000000     7.000000         41.000000         2.000000
# 50%         5.000000    21.000000        114.500000         7.000000
# 75%         5.000000    50.000000        268.750000        15.000000
# max         5.000000   287.000000       1624.000000        48.000000
#
#        total punctuations  total uppercases
# count         1718.000000       1718.000000
# mean             4.434226          3.710128
# std              5.177685          4.209264
# min              0.000000          0.000000
# 25%              1.000000          1.000000
# 50%              3.000000          2.000000
# 75%              7.000000          5.000000
# max             42.000000         54.000000

# %%
print(df.groupby("verified_purchase").describe())
# Out:
#                   review_rating                                               \
#                           count      mean       std  min  25%  50%  75%  max
# verified_purchase
# False                     900.0  4.315556  1.187805  1.0  4.0  5.0  5.0  5.0
# True                      818.0  4.580685  1.030249  1.0  5.0  5.0  5.0  5.0
#
#                   total words                                               \
#                         count       mean        std  min   25%   50%   75%
# verified_purchase
# False                   900.0  50.271111  36.854098  1.0  23.0  48.0  63.0
# True                    818.0  14.414425  21.041211  1.0   3.0   8.0  17.0
#
#                          total characters                                      \
#                      max            count        mean         std  min    25%
# verified_purchase
# False              282.0            900.0  268.920000  199.070130  4.0  126.0
# True               287.0            818.0   77.735941  113.775095  2.0   18.0
#
#                                          total stopwords                       \
#                      50%     75%     max           count       mean       std
# verified_purchase
# False              247.0  335.00  1541.0           900.0  13.838889  8.256163
# True                44.5   90.75  1624.0           818.0   4.216381  5.440307
#
#                                               total punctuations            \
#                    min  25%   50%   75%   max              count      mean
# verified_purchase
# False              0.0  8.0  14.0  19.0  48.0              900.0  6.837778
# True               0.0  0.0   2.0   6.0  44.0              818.0  1.789731
#
#                                                       total uppercases  \
#                         std  min  25%  50%  75%   max            count
# verified_purchase
# False              5.607709  0.0  3.0  6.0  9.0  42.0            900.0
# True               2.893422  0.0  0.0  1.0  3.0  28.0            818.0
#
#
#                        mean       std  min  25%  50%  75%   max
# verified_purchase
# False              5.143333  4.467720  0.0  2.0  4.0  7.0  54.0
# True               2.133252  3.243386  0.0  1.0  1.0  2.0  52.0

# %% [markdown]
# ## Findings
#
# 1. Overall, we can see that False reviews have more words per character than True Values, where False values have an average of 50 words and 268 characters, while True values have about 14 words on average and 77 characters per review.
# 2. Witin the Fake reviews, it can be observed that there are more stopwords as well, than True reviews.
# 3. Since they are longer sentences in False values, it can be seen that there are more punctuations and Sentence case than True values.

# %%
#PIE CHART ON VERFIED PURCHASES -two
colors = ['#FED8B1','#79BAEC']
plt.figure(figsize=(4,4))
label = df['verified_purchase'].value_counts()
plt.pie(label.values,colors = colors, labels=label.index, autopct= '%1.1f%%', startangle=90)
plt.title('True and False Reviews Count', fontsize=15)
plt.show()

# %% [markdown]
# Even after dropping the duplicates, we can still that our data is balanced

# %%
sns.catplot(x ='review_rating',kind="count", hue="verified_purchase", data=df)
plt.xlabel("review_rating")
plt.ylabel("count of reviews")
plt.title("Review_Rating Grouped by Verified_Purchase")
# Out:
# Text(0.5, 1.0, 'Review_Rating Grouped by Verified_Purchase')

# %% [markdown]
# ## Pre-Processing
#
# - Text preprocessing is a technique for cleaning text data and preparing it for use in a model. Text data comprises noise in the form of emotions, punctuation, and text in a different case, among other things. When it comes to Human Language, there are many different ways to communicate the same thing, and this is only the beginning of the difficulty. Machines cannot comprehend words; they want numbers, thus we must convert text to numbers efficiently.
#
# - From the summary statistics conducted, we can see that the noise mentioned are having occurences within the review text, and hence the pre-processing will be conducted accordingly.
#
# ### To Do
#
# - Drop unwanted columns
# - Lowercasing
# - Remove Stopwords
# - Remove Punctuations and Special charas
# - Stemming

# %%
#Drop unnecessary columns
df.drop(["total words","total characters",
         "total stopwords","total punctuations",
         "total uppercases","review_rating"], axis=1, inplace=True)
df.head()
# Out:
#                                          review_text  verified_purchase
# 0  As you get older, you know what you like and w...               True
# 1  Three gigantic marmite jars that will last pro...               True
# 2                                          Excellent               True
# 3         A great flavour top - up for slow cooking.               True
# 4                          Does what is says it does              False

# %%
#CORRECT SPELLING
df.review_text.apply(lambda i: ''.join(TextBlob(i).correct()))
# Out:
# 0       Is you get older, you know what you like and w...
# 1       Three gigantic marie wars that will last proba...
# 2                                               Excellent
# 3              A great flavour top - up for slow cooking.
# 4                               Does what is says it does
# 5                             Excellent item.Good for men
# 6                               Thank you ofm very happy
# 7                                               Beautiful
# 8                                 Always buy. Fig bottles
# 9       Always use this product on my heavily mistreat...
# 10                                            Great value
# 11      tos not the one in the picture, but gets 5 st...
# 12      Stem as described, excellent quality, rapid de...
# 13             Good body wash but not a very strong smell
# 14                                                  Great
# 15                                              North it!
# 16      I remember trying this at a friends house year...
# 17                                                  Great
# 18      Not the best antiperspirant out there unless y...
# 19                                      Love this product
# 20      Of I die eating one of these I\u2019ll die a v...
# 21      I love this range of body lotions as they aren...
# 22      I suffer with dry sensitive skin and vaseline ...
# 23      Absolutely love this stuff ... leaves a lovely...
# 24                                     Very happy with it
# 25      I love that I now wash my cashier waters at ho...
# 26      To prior to receiving this I had pretty rough ...
# 27                                        Happy with item
# 28      I really like this. The texture is almost like...
# 29                                            Smells nice
# 30      A great deal on presume shampoo giving a long ...
# 31                                            Great value
# 32                                      Love this comfort
# 33                                              Horrible.
# 34                                            a great buy
# 35      Love the container, easy to pour, but am refil...
# 36                                      Ashes sparks well
# 37                                              excellent
# 38      Good pleasant smelling deodorant boys will lov...
# 39      delivered quickly and decent shampoo. only 4 s...
# 40      Have used a lot of make-up bands and in the pa...
# 41      not sure why the big jar costs more than doubl...
# 42      Not this on offer for Â£6, clothes come out ve...
# 43      For Â£6 this is an amazing buy- lasted me mont...
# 44                             Great buy, smells gorgeous
# 45                     Texture liked.used for bath/shower
# 46                                     shared with family
# 47         He love it and even better when its on a deal
# 48                                         Great product!
# 49      Ought items to give as gifts, it was advertise...
# 50      Good price and nice smell, not overpowering. d...
# 51                                   Good wiped, good buy
# 52      Vice fragrance and it seems to last on the clo...
# 53      I've been Using tresemme products for years. P...
# 54          To much cheaper than in Boots. Great value!!!
# 55      I like the blue version but this is such an ov...
# 56      I like these, I use only one in the regular wa...
# 57          Excellent value and you don't had to carry it
# 58                                                Washing
# 59                                     Lovely fresh smell
# 60                                             great item
# 61      thats not to like nodules that taste like spa...
# 62      His is a good deodorant if you have easily irr...
# 63                Great body wash. Heap and fast delivery
# 64      yet to try the taste but why, in this day and ...
# 65      Not even worth one star. Bring out a lot of wh...
# 66                             Ought this for my step dad
# 67      Love this on my of. It smells so good on him b...
# 68                                             Great gift
# 69      His is a classic and you know when its Hellman...
# 70                                                   Fool
# 71      Absolutely great moisture for dry skin. An com...
# 72                                      Great package buy
# 73                         Works well and truly invisible
# 74                                Vice and cost effective
# 75                                                  Great
# 76      Does exactly what it says my kitchen sink is a...
# 77      His is my favourite scent from the intense ran...
# 78      I find these to be the best for my sundry and ...
# 79         And under 150 calorie for a really big portion
# 80      The cream is very easy to apply and feels extr...
# 81      Excellent product, made my skin feel silk smoo...
# 82      His cream is light, colourless and leaves the ...
# 83                     Fresh and clean. Reliable delivery
# 84      Great combination, started using when my now m...
# 85                       Vice and fresh smelling products
# 86      He all grave things that transport us back to ...
# 87      Lovely, but can be bought cheaper in home barg...
# 88      Stem was damaged and unable to pour without pi...
# 89                                            Good price.
# 90                                     It came very fast.
# 91      I Simple!His is my absolute must-have facial m...
# 92      Please go back to the old capsules - these new...
# 93      Never usually use sundry softened but was very...
# 94      I am a marie lover. I have switched back to th...
# 95                                                  Great
# 96                                              Thank you
# 97      I got this and its be a great buy. ont have ...
# 98      I had been lured by all the entering fragrance...
# 99      Gives a good result - the fragrance is very st...
# 100                                                  Good
# 101                                       Good size spray
# 102     The price of this bulk pack is less than buyin...
# 103     Like to make my own soups & casseroles. His pr...
# 104                               The best ice cream ever
# 105     I live in an extremely hard water area half th...
# 106     Easy to use. I will recommend it if you want t...
# 107     Disappointed shows big conditioned but small a...
# 108                            He all know how this works
# 109     doesnt clean my clothes too well and if there...
# 110                        I would recommend - good value
# 111                          I will be buying again thank
# 112                             That more is there to say
# 113     Always been a fan of dove products. Antiperspi...
# 114                         Is expected - repeat purchase
# 115                             Excellent value for money
# 116                       Excellent cleaning. Good value.
# 117                                    Very happy with it
# 118                                       Excellent value
# 119                                   Great Value shampoo
# 120     Exactly wat it says on the box but for an amaz...
# 121     ofve both exact a similar 5 litre one from Os...
# 122                 Amazing offer price. Wouldn't resist.
# 123     I have hands that are really dry and bleed due...
# 124                          To issues, does what it says
# 125     Need I say more. Use them all the time for sou...
# 126     I simply love this deodorant. The scent is gre...
# 127     Chicken gray really well and add a wonderful f...
# 128                           Amazing and great price too
# 129             Smells great, easy one handed application
# 130                    Very good value I would recommend.
# 131     Body deodorant we love the smell and great val...
# 132     The only floor cleaner I use. It smells good a...
# 133                                         Brilliant buy
# 134                                       Value for money
# 135     All fabric conditions work more or less the sa...
# 136     Wouldn't find any in shops so bought on-line. ...
# 137     Been using this for a year, very happy. Last 2...
# 138     I have been buying this for years. The content...
# 139     Pleasant to use with very little scent, which ...
# 140     These wiped are great for getting the most stu...
# 141     Great quality wiped that are strong to use and...
# 142     I love these face wiped as they do at great jo...
# 143     I have sensitive skin, but these worked really...
# 144     Been using for a few months Really pleased how...
# 145     Cried and tested this skin munching night crea...
# 146     Happy with this product. Very light on the ski...
# 147     His is a great water based moisturiser, that i...
# 148     His is another great product from Simple, so d...
# 149                                           good flavor
# 150                                                 great
# 151                  To question as it says on the bottle
# 152            Very good value. By favourite conditioned.
# 153                                          lovely smell
# 154     Love the product, however its hard to spray. ...
# 155     Not this to try and want disappointed. Its a l...
# 156                              A little goes a long way
# 157     Not convinced that smell matches original, see...
# 158     His is such a great soap. He and my wife loves...
# 159     Love these soap, clean well and keeps your han...
# 160     Definitely worth the money! I do sundry very o...
# 161     Arrived super fast. Two good sized bottles. I ...
# 162                      Great product very happy with it
# 163     Great price at Â£6 when i purchased. Of it was...
# 164     Lovely smell, can pour into smaller bottles to...
# 165     These pads work as well as any other I've used...
# 166     I love Comfort Sure. Both our children have se...
# 167                                                Thanks
# 168                                             It watery
# 169                                                  Good
# 170     Blue bottle is clot better. His smells less th...
# 171     Great value for money, smells nice and seems t...
# 172                                          Good product
# 173     Product arrived broken and had spilt all over ...
# 174                              did not squire very well
# 175     Very good value for the amount of capsule you ...
# 176      It too funny,not as thick liquid as most but ok.
# 177                                           Works great
# 178     I have used Simple Rich moisturiser for years,...
# 179                             excellent value for money
# 180                     These are great. I will buy more!
# 181               But that's personal taste. Old mine on.
# 182                  All three of the favours are so good
# 183     I have tried many English mustard in my time b...
# 184     Is the title suggests, I really wont buy any o...
# 185                 His is breach. Bleachy breach breach!
# 186     I have been buying this shampoo for my husband...
# 187     His Love deodorant stick is the best deodorant...
# 188                                         Great quality
# 189     Buy this on my amazon prime orders, no problem...
# 190           Great product, lovely scent. Lasts me ages.
# 191                                                    A+
# 192                                    Ashes clothes nice
# 193     Great taste and adds depth of flavour to any m...
# 194     Years ago I used to love pot nodules as a stud...
# 195     While I like the product, the bottle is unsuit...
# 196     I love lynn products so was happy to buy this ...
# 197                                               perfect
# 198                            Great product! Great price
# 199     They last forever, work well and I now wouldn'...
# 200                                                  Room
# 201     Some very considerate friends brought this to ...
# 202     Product is fine. But I struggle to get the smo...
# 203     I always buy this product, I love it. It's a q...
# 204      I love this product It's keeps my hair protected
# 205                                       Happy with item
# 206     Brilliant product! Left the drains clear and c...
# 207                                           Great value
# 208                                                  Line
# 209     I'v bought loads of these on offer. Used 3 was...
# 210     I bulk bought these as don't drive and they ar...
# 211     Quite a solid product, I find it easier to use...
# 212                                     Good Round Thanks
# 213     3 pouches arrived in a peril box in a brown bo...
# 214     Fantastic price and my mother-in-law loves thi...
# 215                                         Well worth it
# 216     His doesn't seem to be genuine...the branding ...
# 217               To idea how they can claim 100+ wishes?
# 218                                          Like product
# 219     andt get this where I live so this was dead h...
# 220                                       Love this smell
# 221                         smells good and not expensive
# 222                                                  Good
# 223     I love this! ofve been using it for the past ...
# 224                                  Good value for money
# 225     I dont know how anyone can like this..it smel...
# 226     Struggle to open the lid, then it pills every ...
# 227     Have used this for many years with no problem,...
# 228     I bought this a week ago and having tried many...
# 229     Good value for money- but the container does m...
# 230     Never buying again. About 15 of the capsules w...
# 231     Good cleaning product of you have kiss with se...
# 232                     A nice mustard - smooth and taste
# 233                                                 Great
# 234     Over prices and over rate, but it's what the n...
# 235     Of your looking for a super moisturizing body ...
# 236     I love this body was my skin gets super dry in...
# 237     I use this on both myself and the kiss. He all...
# 238     His body wash has a soft original \"dove\" ori...
# 239     His is what I use in the winter. It helps to k...
# 240     Feels like Am really getting clean and I love ...
# 241     Love how soft my skin feels after using this p...
# 242                                             Very good
# 243     Huge bottle, smells lovely with clothes drying...
# 244     I wouldn't buy this again. Frequently it leave...
# 245         They have a great smell and clean brilliantly
# 246     Package is not comfortable and spilt few times...
# 247                          great price i will but again
# 248     Love the size of the bottle, the smell is gorg...
# 249                                  Cab stocking filler.
# 250     Great buy I use this before I blow dry my hair...
# 251     Not happy yet probe my fault couldnt get the ...
# 252     The conditioned itself is good. However, the b...
# 253                                    you cannot beat it
# 254                                         never changes
# 255     Amazing smell! And the skin looks really healt...
# 256                              maybe 12 was too many :)
# 257                                         perfect price
# 258     Arrives with a broken lid leaned all over the ...
# 259     very good value set - I took a star off as I e...
# 260     Stocked up to save money - quite strong smell ...
# 261     love this creamy soap would not use anything e...
# 262                                                  Good
# 263     Vice smelling and great anitipersperiant, also...
# 264     Love this product works really well and protec...
# 265                                                  Good
# 266     Takes your hair smell great. Definitely, recom...
# 267                      Amazing and came in perfect time
# 268     I always take Badedas when I go on holiday, it...
# 269     Sorry to say this but it tastes awful, creates...
# 270     Our go to sundry detergent, this works, even a...
# 271                            Vice smell and last longer
# 272                              I love the smell of this
# 273                            Met usually Lynn standards
# 274                          Lovely scent and a good wash
# 275                                             Excellent
# 276     His cream burn my skin And I have a lot of spo...
# 277     I never use anything else. Soft, creamy and ha...
# 278     I have bought this product many times. It is t...
# 279     I love the scent, smells somewhat like baby po...
# 280     Perfect for a quick snack. Brilliant to no my ...
# 281     I love this soap. It leaves my skin feeling sm...
# 282                                   Smells really fresh
# 283     I signed up for a subscription as such great v...
# 284                                           Great value
# 285     Smells nice, creamy texture and meant dry our ...
# 286     I used this product for literally 10 years, no...
# 287     smells divine so easy to use glided on skin sk...
# 288     Smells aaaaaaaaamazing and fresh and great val...
# 289                                                 Drill
# 290                             Vice smelling shower get.
# 291     thats not to love, its decent fabric softene...
# 292         SMELLS NICE AND THE CLOTHES ARE NICE AND SOFT
# 293     Love the smell of this comfort buy all the tim...
# 294                                        Smells amazing
# 295              Smells nice keeps clothes smelling fresh
# 296     It doesn't smell good and doesn't last for a l...
# 297     Cheaper to get than having to ask attends for ...
# 298     Usually purchase at Osteo but these are extrem...
# 299     May as well just use plain water, it would do ...
# 300                                       Perfect flavour
# 301                                                     K
# 302                                                Sundry
# 303                                                  Vice
# 304                                           Great value
# 305     Recent price. A lot cheaper than in store. Las...
# 306                      Vice  i will prefer to buy again
# 307                   Great for hair that is straightened
# 308                     Great product and great price too
# 309                            Does what it's supposed to
# 310     They arrived and they're pot nodules. That mor...
# 311     The recommended amount does not refresh the fa...
# 312                           Smell nice but just hours:D
# 313     Not happy with this product, Â£11 for its its...
# 314     I have very dry skin and this keeps me moistur...
# 315     I like this fabric softened. Have tried others...
# 316     Have one jar away as a gift and still have two...
# 317     Smells Divine. Lovely and fresh Fragrance last...
# 318                         Good price, good washing pads
# 319     I found this cream very absorbing and non grea...
# 320     I have been through 5 bottles now this stuff i...
# 321     Ought these as a treat for my children and I. ...
# 322     what happened to your lovely cream eyemake up ...
# 323     I was very sceptic about using this soap , but...
# 324     I tried the Simple hydrating cleansing wiped d...
# 325     Recently true these soon wiped and they are fa...
# 326     Please please do this in a magnum tub incised ...
# 327     The shower get is very mild yet gives you a ni...
# 328     By skin is quite sensitive to body wash and of...
# 329     Cried this product for first time today. Packa...
# 330     To artificial perfume or colour, no harsh chem...
# 331     I love all simple products-. His shower get ma...
# 332     I\u2019ve been using this shower get a while a...
# 333     Love it very nice to apply to your sponge to h...
# 334     I got this a couple of days ago and used when ...
# 335     His product leaves a lovely fragrance to your ...
# 336     After pouring a cupful of this white gold into...
# 337     Sainsbury's Cheddar Cheese Sauce Six fig is sc...
# 338     I really enjoyed how luxurious this shower get...
# 339     Perfect for sensitive skin! The shower get is ...
# 340     Love this shower get, it does exactly what it ...
# 341     Great shower wash, even though it had cucumber...
# 342     When I got this, I was a little concerned beca...
# 343     I love the smell of this shower get, smell qui...
# 344     I\u2019ve been using this for around a week no...
# 345     Simple refreshing shower get really great for ...
# 346     I use most of the simple products range, as I ...
# 347     I have used this shower get for a few mornings...
# 348     I bought this about a month ago and can stop r...
# 349     Love this Simple Shower El ,it's not like some...
# 350     I like Simple as a brand as it does feel very ...
# 351     It is a very neutral product. It\u2019s cheap ...
# 352     I have very reactive skin because of eczema. I...
# 353     Amazing product! By skin feels super soft to t...
# 354     Must as I expected from a simple product! Vice...
# 355     Simple great as ever! I have always been a gre...
# 356     Really gentle and cleansing, not a very strong...
# 357     I ve been using this for over 1 week now and I...
# 358     I love this shower get, has a very fresh scent...
# 359     I use simple between other bands as my skin br...
# 360     I've bought this shower get a few times whenev...
# 361     By skin always feels so dry after I shower. Ho...
# 362     I just love simple products as I know they are...
# 363     From the simple range so not full of parties a...
# 364     I thought I would give this shower get a whirl...
# 365     To I tend to use another soap free brand and I...
# 366     I love that this shower get has no perfumed an...
# 367     Didn\u2019t irritate my skin, instead it felt ...
# 368                                               Perfect
# 369                  It was spilled everywhere in the box
# 370     Absolutely love this scent. Takes your clothes...
# 371     I picked up in a rush in store and am so pleas...
# 372     I usually buy organic cosmetic and wanted a na...
# 373     The mayonnaise would get 5 stars from me for t...
# 374     His ice cream is great. The cook dough pieces ...
# 375                          By nightly treat. Perfection
# 376                 Must perfect and even better on offer
# 377     Is far as I'm concerned these are the best. Re...
# 378     I've tried clot of breaches and other toilet c...
# 379     Ve tried many alternatives, and the only mayo ...
# 380                    more than half the bags were split
# 381     Good value for money. Wash really well, lovely...
# 382     I love this range of body lotions as they aren...
# 383     I am very happy with the Vaseline intensive ca...
# 384     His morning I received a bottle of Vaseline al...
# 385     I suffer from dry skin from ages , and I am al...
# 386     His cream is one of the best body dreams I've ...
# 387     His is a decent everyday lotion with a clean l...
# 388     Lovely day cream makes my skin feel lovely,hel...
# 389         Great product and arrived quickly. Vice scent
# 390     Arrived on time, well package, great product. ...
# 391     Really good value for money, perfect for washi...
# 392     The product has leaned over all my order, do y...
# 393                           Love the smell and softness
# 394     Excellent product, having been using it for aw...
# 395     Started using this as I could not find my old ...
# 396     I loved the sweet smell of this body lotion. T...
# 397     I use body lotion but had never tried the Vase...
# 398     I got this a couple of days ago and used it af...
# 399     His lightly fragrance lotion dispense easily f...
# 400     He've been using this for months. It's a lovel...
# 401     I suffer from bad dry skin during the winter a...
# 402     Love this cream. It heavy but not overlay so, ...
# 403     Winter has left me with very dry skin, especia...
# 404     I suffer from dry sensitive skin and vaseline ...
# 405     Love how light and none sticky this moisturise...
# 406     tos what we usually use so getting this big c...
# 407     Bargain,however I dont think the consistency ...
# 408     Great value for money. Fantastic product. Love...
# 409     I do like the Simple brand products as I have ...
# 410     Event tried this as its for hamper in making f...
# 411     Removed stains and keeps washing in great cond...
# 412              An't beat the price smells clean love it
# 413     Awful, dont buy!!! Pipes are too thick, like ...
# 414             Smells beautiful and well worth the money
# 415     Easy just throw in drum and thats it. To mess...
# 416     His product is anything but gentle. It really ...
# 417     I was given this product to review & think it...
# 418     His is my first time using Vaseline intensive ...
# 419     I used this lotion when I got out of the bath....
# 420     Great product, very well package and great price.
# 421     Excellent value bulk buying saves money in the...
# 422                                                     K
# 423     Of you like this deodorant and can afford to b...
# 424                         Arrived ok, good item thanks.
# 425     Good quality conditioned - not watered down, l...
# 426                                         great product
# 427      Great thank you came 2 days later! Smells lovely
# 428     I have used mosturier in the past where it cau...
# 429     I liked this product, it makes skin so soft an...
# 430     His is one product that I think every househol...
# 431     I suffer from really dry skin in the winter mo...
# 432     His time of year my skin tends to become dry a...
# 433     I struggle with finding a moisturiser which la...
# 434     I tried this lotion and firstly couldn't get e...
# 435     To prior to receiving this I had pretty rough ...
# 436                         Last delivery, great product.
# 437     Reliable product even at cooper cases and love...
# 438     Value for money. Vice smell, my daughter loves...
# 439     Girlfriend wasnt too pleased but still said a...
# 440                                         Great product
# 441            Scrumptious, authentic Not Goodge flavour.
# 442     and it was on offer half price so most pleased...
# 443                                     Lovely ice cream.
# 444     Love marie, but feel like waste a lot in this ...
# 445     Husband said this was sharp to begin with but ...
# 446     I dont like chocolate ice cream...... however...
# 447     Rich and full of flavour. Well loved by all th...
# 448     One of my favourite chocolate ice dreams. I es...
# 449                       Smells lovely and does the job!
# 450     Very subtle (my preference) but lovely fragran...
# 451     A great handwash, that smells delightful. Usef...
# 452                          Thick and creamy smelt fresh
# 453              The frozen pear scent is really pleasant
# 454     Was sent this to review so I gave it to my hob...
# 455     Fantastic cream, skin looks and feels like jus...
# 456                          By nightly treat. Perfection
# 457     Right need to only use a tiny bit... the smell...
# 458     Of your looking for a super moisturizing body ...
# 459     I use this on both myself and the kiss. He all...
# 460     His body wash has a soft original \"dove\" ori...
# 461     I love this body was my skin gets super dry in...
# 462     His is what I use in the winter. It helps to k...
# 463     I just used Love Deep Moisture to shave pretty...
# 464     Feels like Am really getting clean and I love ...
# 465     I have tried other Vaseline body lotions and I...
# 466     I have tried this product and I'm impressed. I...
# 467     Love how soft my skin feels after using this p...
# 468     Absolutely fantastic, I find my skin goes so d...
# 469     Ve used this a few times...in the mornings nig...
# 470     Love this product. Lovely fresh smell and leav...
# 471     I got this a few weeks ago now and I have used...
# 472     I have been using this for a few days and I re...
# 473     His has a nice aloe scent and smooth on nicely...
# 474     I really like this, it does seem to moisture b...
# 475     I love this product, it is amazing. By son suf...
# 476     I used this product for 1 week and it has give...
# 477     I have very oily skin so finding a moisturiser...
# 478     I have been using this for years and it works ...
# 479                                                  Roof
# 480     Is actually good and practical to use the pot....
# 481     Really Happy good quality and value recommend ...
# 482     Large bottles. Shampoo improves hair. Shiny an...
# 483     Takes your hair oily. Yes it can protect but t...
# 484     Great value for money. Good for most hair type...
# 485                                            Vice smell
# 486                                         Smells lovely
# 487                                            Good value
# 488                          Good value pack fast service
# 489     West deodorant brand that always deliver, smel...
# 490                              Good value for the price
# 491                                            Good value
# 492                          Great to better. Smells nice
# 493     Really does work well and a pleasant smell. Do...
# 494                     Love this comfort,smells so fresh
# 495     Smells gorgeous huge bottle last ages ! bought...
# 496                                                  Good
# 497                     Smells nice. Soft and static free
# 498     I like because it is perfumed and that is vita...
# 499     Smells so nice and leaves clothes smelling nic...
# 500     Smells good and keeps the pits dry. An't go wr...
# 501                                           Is expected
# 502                                        Its shower get
# 503     Excellent price and size, especially how much ...
# 504     Excellent value for the price.... in fact I bo...
# 505                 Lovely smell last for ages on clothes
# 506                                                 Great
# 507                 Great as a multi pack on subscription
# 508     His is what the better half wanted and is chea...
# 509     That can I say, does the job, pleased with pur...
# 510                                  and work as expected
# 511     Hard to get on hands and you think that you ha...
# 512     Purchased these as they were cheap but I reall...
# 513     Bandy things to keep in the cupboard, they're ...
# 514     I use Partite on sausages instead of mustard. ...
# 515                              Good price fast delivery
# 516                       keeps the home fresh and clean.
# 517                                                 Like.
# 518     Absolutely love these comfort Creation fabric ...
# 519     His is the best shampoo I've ever used. It mak...
# 520                       Brilliant quality for the price
# 521     I absolutely love this deodorant and it's so m...
# 522                              Good value for big pots.
# 523                                                    5*
# 524     I love this scent and to get it on offer was a...
# 525     Really pleased with this conditioned. Smells l...
# 526     Lovely smell however a few bottles were only h...
# 527     Ought in bulk and I'm still working my way thr...
# 528     Not the quality that i expected from Peril.The...
# 529                            He dont buy anything else
# 530                     Keeping the washing machine going
# 531                                       Excellent value
# 532                                                  Good
# 533                                               Quality
# 534     I use 2 at a time as I always have large loads...
# 535     I always go for Peril as its non big and its...
# 536     I didnt read the about details correctly. to...
# 537     Head a few post Amazon were selling these 38 w...
# 538                             Excellent value for money
# 539     Brilliant price, happy with my purchase. Shoul...
# 540        It is what it is and my wife was happy with it
# 541     It's got a fully smell and it saves my carryin...
# 542      Tiny little bottles that are not worth the money
# 543     A treat much appreciated by my husband we are ...
# 544     I do not an on sunbeam and spray tens dont ta...
# 545                          Very effective washing pads.
# 546            Perfect. Peril is the best. Last delivery.
# 547                 andt go wrong Said Â£15 for 3 packs.
# 548     Although these were a great price, i have come...
# 549           Smells divine ! Will definitely recommend !
# 550              To so happy with this so worth the money
# 551     He bought this to save lumbering home large bo...
# 552                                 He always use comfort
# 553     Now do I know that this is actually comfort pu...
# 554     Seemed to have some product missing out the bo...
# 555                                          Does the job
# 556     The family loved this! The marshmallow is part...
# 557     The ice cream was smooth but very indulgent. T...
# 558     The whole family really enjoyed this ice cream...
# 559     His ice cream is nice, has different texture w...
# 560     A lovely ice cream, nice chinks of chocolate a...
# 561     I usually buy the Or Muscle one. All go back t...
# 562     Great product, I used this for the first time ...
# 563     Winter is really taking its toll on my skin an...
# 564     I have tried this product and was totally impr...
# 565     Decidedly smaller than a normal Magnum and the...
# 566     Gentle with a lovely lather. Not so keen on th...
# 567     Any thanks to Cady for this free trial product...
# 568     I wouldn normally choose chocolate ice cream a...
# 569     I received a tub of this to try. He had it for...
# 570     Of you want a sweet rich chocolate ice cream, ...
# 571     Ought these thinking they were the ordinary si...
# 572     I have of and my skin can get burnt from bladd...
# 573       Very good product, excellent for every day use.
# 574     His shower get smells very nice and is quite t...
# 575     Great product, very concentrated and good ling...
# 576     All the family love it! Great chocolate ice cr...
# 577                  Everyone loved this. Will buy again.
# 578     I've been using this moisturiser daily for 5+ ...
# 579     I just try this product and so happy with it. ...
# 580     Now i love this so much,the smell is amazing a...
# 581     I would very much recommend this product, afte...
# 582     His product is not what I would have bought. A...
# 583     His product smells gorgeous. I have used this ...
# 584     By husband used this deodorant and found on ap...
# 585     I poured this in kitchen sink drain and left i...
# 586     Of you like chocolate icecream then this is a ...
# 587     Lovely creamy with good chocolate flavour. Con...
# 588     I have always used If and thought it a great p...
# 589     why change what was great - no option for no s...
# 590     His is the best stock ever-unless you make you...
# 591     Shame they contain palm oil (albeit labelled '...
# 592     By husbands favorite - but impossible to find ...
# 593     I'm really impressed! His was my first time us...
# 594     A lovely subtle and soft colour to the skin. I...
# 595     Is a regular user of a number of simple produc...
# 596     I love having a shower in the morning and more...
# 597     I got this product a few days ago and used it ...
# 598     I love the simple range! It's great for my sen...
# 599     I always use simple products so when I got the...
# 600     Simple refreshing shower get. Personally. Didn...
# 601     His is a really good shower get for sensitive ...
# 602     Must like the rest of the simple range, this p...
# 603     His Simple shower get is a clear get that fath...
# 604     I always been a big fan of Simple shower gets ...
# 605     Love this shower get mostly for its simplicity...
# 606     His shower get really is simple to use. A smal...
# 607     Not for my husband for a change. Classic lynn ...
# 608     By skin was dry, itchy and scaly and no matter...
# 609     His body lotion is generously sized and lasts ...
# 610     of only used this Vaseline intensive care Aloe...
# 611                                      Works like magic
# 612     Great value for money!!! Great buy, I didn't t...
# 613                                Means hair well though
# 614                                           Good value.
# 615           Fig bottle, low cost. Gets not go too deep.
# 616     Thought I was getting a bargain but found it c...
# 617     His is absolutely indistinguishable from the f...
# 618     Liked this, fathers up nicely and has a lovely...
# 619     Recent size bottle, with a firm lid. The smell...
# 620                                     Lovely and fresh!
# 621     Obviously....chocolate. ice cream. what more t...
# 622     He really enjoyed this, creamy ice cream with ...
# 623     Really lovely rich creamy ice cream. Went down...
# 624     Vice flavour, although very very sweet and tex...
# 625     It's very good looked it good price and it big...
# 626                                            for snacks
# 627                              Great value good service
# 628                             Brilliant value for money
# 629                                       Love it love it
# 630     Like the smell, fathers well and a little goes...
# 631              Long lasting scent and barely any sweat.
# 632     large packs, works out cheaper than the shops....
# 633     I have used this deodorant for the last 5 year...
# 634                                           Is expected
# 635             The original smell of teenager in the was
# 636     That a treat! Thank you Cady for sending this ...
# 637     I was sent this product to review, love the ne...
# 638       Feels nice on the hands, and aroma isn closing.
# 639                                            Convenient
# 640                 Always bulk buy tresmemme from amazon
# 641                            Haste horrible and so hard
# 642     First off love it after that what's left to sa...
# 643     They are a little bit rough, I dont know why ...
# 644     That's not to like? Awesome, long-lasting qual...
# 645                       Fantastic buy. Speedy delivery.
# 646     Great price for 2 large shampoos. Tresemme is ...
# 647     The bottle was on its side and the seal was br...
# 648     Love the smell and wishes great. Unfortunately...
# 649     It was spilled everywhere in the box again. Pl...
# 650     Is actually good and practical to use the pot....
# 651              Lids love this, great chocolate flavour.
# 652     His is an ice cream classic. I enjoyed it when...
# 653     probably out least favourite Men & Merry ice c...
# 654     His is a great everyday moisturisor for all sk...
# 655     Whenever we but these they never contain any w...
# 656                                One of many favourite.
# 657     Absolutely gorgeous. Rich, good, marshmallowey...
# 658     By children love this flavour, I think it is t...
# 659     He have hard water, and have had problems with...
# 660     Ve used Simple products before as I have sensi...
# 661     To happy that I chose to buy this as it is inc...
# 662     I'm really impressed! His was my first time us...
# 663     By husbands favorite - but impossible to find ...
# 664     His and Cookie Rough are the best Men and Merr...
# 665     Hats not to like! Dreamy, very chocolate wasti...
# 666     Love this size of magnum as much better for a ...
# 667                                         Excellent buy
# 668                                         You are wrong
# 669     Literally no carry powder or anything on the n...
# 670                               I like this conditioned
# 671     Last delivery. Nicely packed, makes my washing...
# 672     Must opened it all the liquid came out all ove...
# 673                                         Excellent buy
# 674     That's to say of the taste beef and tomato? Mu...
# 675            Haven't tried it yet but the smell is nice
# 676     I recently developed eczema for the first time...
# 677     I am quite enjoying using this concealed at th...
# 678     I was stoned so need more pot and with this po...
# 679                                 That was a good deal.
# 680     It is very sweet but in small portions makes a...
# 681     I mean, guns, it's amazing. Those little choic...
# 682     not my usual flavour but tried this for a chan...
# 683            Thoroughly recommend great clean and smell
# 684     Cheapest ofd found at Â£6 for the quantity yo...
# 685     The only deodorant I'll ever use and have done...
# 686     I2019ve been buying these for years now becaus...
# 687     These are the best make wiped I've ever tried!...
# 688           Was repaired all my dry ends.... INCREDIBLE
# 689     Exactly the same as you would buy in the shops...
# 690     I've been buying these for years now because t...
# 691     It about 400 cal, this is definitely no soup f...
# 692                                  Rate value for money
# 693                             Product burst in transit.
# 694     Leaves clothes smelling lovely and keeps them ...
# 695                                             Recommend
# 696     i have an autoimmune disease called dermatomyo...
# 697     To happy I tried these make up wiped. I have s...
# 698     These are super easy to use,I have them in my ...
# 699                 By man favourite and I love the smell
# 700     To happy I tried these make up wiped. I have s...
# 701     I absolutely love this an, I've tried the so m...
# 702     I live on my own but the jar never goes out of...
# 703     A tub never lasts long in our house as its so ...
# 704     Absolutely delicious! Strangely, the kiss were...
# 705     Case of use is an obvious advantage and clothe...
# 706     Perfect stay moist in the packet instead of dr...
# 707     I am so glad I tried These wiped I've been sea...
# 708     I love using cellar water to clean my skin and...
# 709     I received these today and oh my god they are ...
# 710     I have bluish prone skin, so using a good qual...
# 711     I like this product because when i used it it ...
# 712     I used it once I got it. It keeps my skin quit...
# 713     His is one of the most unfordable yet effectiv...
# 714                            Smells really pleasant....
# 715                Our whole family loves this ice cream!
# 716     I used it once I got it. It keeps my skin quit...
# 717     Absolutely of nutrition in these whatsoever..y...
# 718     Used in a chicken and mushroom pie filler. Tho...
# 719                                    Lovely smellllllll
# 720     I have always been a fan of cellar water for y...
# 721     nice wiped, takes out the whole make up, you d...
# 722     To gentle on skin. Feels just like water... Ev...
# 723     I2019m so happy with these wiped! I have used ...
# 724     His foundation is really lovely, light and smo...
# 725     His wash worked very well. It removed my make ...
# 726     I absolutely love Simple products and its one ...
# 727     I found this face wash very kind to skin , nor...
# 728     started using this a few days ago and I2019ve ...
# 729     Been using this for the last few days this fac...
# 730     I am very conscious of what I put on my face a...
# 731             In old favourite which never disappoints.
# 732     Revolting. Tastes nothing like real vanilla ic...
# 733     The ice cream is creamy, delicious chocolate t...
# 734     I'm so happy with these wiped! I have used the...
# 735                                        Usual Standard
# 736     Used this conditioned for years! Others often ...
# 737              Thankyou just what I thought it would be
# 738     His product is great, I got this a month ago m...
# 739     Now! That an amazing product! The difference i...
# 740     I love these wiped, I have been using them for...
# 741     These are excellent wiped that are perfect whe...
# 742     Brilliant for taking away my make up sins it d...
# 743     I bought the facial wiped a week ago. The pack...
# 744     By skin feels so fresh after using this produc...
# 745     I2019ve been using this face wash for years an...
# 746     I am very conscious of what I put on my face a...
# 747     started using this a few days ago and I've not...
# 748     I've been looking for a body wash that doesn't...
# 749     I've been using this face wash for years and I...
# 750     I bought the facial wiped a week ago. The pack...
# 751     Brilliant for taking away my make up sins it d...
# 752     These are excellent wiped that are perfect whe...
# 753     I love these wiped, I have been using them for...
# 754                                                 Great
# 755     good quality, easy to use - does the job - sob...
# 756     great smell and great value for money. i would...
# 757                                                  Good
# 758     His is a good product leaves a nice smell but ...
# 759     These are not Simple wiped - the quality is si...
# 760      Tastes great, not as spice as I feared it might.
# 761     I bought these simple wiped about a month ago ...
# 762     I bought this a couple of weeks ago and I have...
# 763     I bought these wiped to help clean my face and...
# 764     so i purchased these wiped as i love simple pr...
# 765     I was cautious at first when using these wiped...
# 766     I tried these on a fairly dry watch of quite c...
# 767     Takes my skin feel so soft and clean after use...
# 768     His is an excellent product and left my skin f...
# 769     I have normal/oily skin, I used this facial wa...
# 770     I have not been using this for long and am ple...
# 771     after using this my face felt lovely soft and ...
# 772     Been using this face wash for the last couple ...
# 773     I used this cleansed twice a day, I have combi...
# 774     Having used this face wash for a few days now,...
# 775     In amazing product, which I would highly recom...
# 776     I like this face wash, its gentle on the skin ...
# 777     I wouldn't usually go for a high street produc...
# 778     I used this product and it leaves my skin feel...
# 779     I've been using this product for about a week ...
# 780     These wiped have a lovely fragrance and do an ...
# 781     Cried these wiped instead of my usual ones for...
# 782     I received these wiped a couple of days ago an...
# 783     I went away for the weekend and decided to use...
# 784     I revived this product a week ago now I usuall...
# 785     Vice product, Colourful packing, Smell nice.Th...
# 786     Simple Cellar wiped limited addition (little m...
# 787     I was using comfort sunshine days which also s...
# 788                                               Love it
# 789     His is an excellent product and left my skin f...
# 790     Does what it is supposed to do. Effectively re...
# 791     I got this around a week ago, tried it during ...
# 792     His tone it's great for my skin as it's alcoho...
# 793     I love this tone! I have used it every day sin...
# 794     Happy with the results of this product, it is ...
# 795     Soothing Facial One this is a lovely product w...
# 796     I'm so happy to have received this product as ...
# 797     I have quite dry skin on my face and this tone...
# 798     His is the best thing I have tried my skin fee...
# 799     It's so gentle on your skin and makes it feel ...
# 800     I've always been a fan of simple and this prod...
# 801     I am in really impressed with this tone. I've ...
# 802     Am glad i went back to this tone. D been using...
# 803     I bought these wiped to help clean my face and...
# 804     Vice product, Colourful packing, Smell nice.Th...
# 805     I went away for the weekend and decided to use...
# 806     I revived this product a week ago now I usuall...
# 807     Cried these wiped instead of my usual ones for...
# 808     I love Love soap, the bar and the liquid soap ...
# 809     Love this body wash, all the dove line is a fa...
# 810     Not a big fan of Love. It doesn have much of a...
# 811     By skin is SOFT after one wash of this stuff, ...
# 812     Been using this body wash recently and it work...
# 813     I love this body soap because its like applyin...
# 814     It is very moisturizing! It has such a pretty ...
# 815     His is a pretty good body wash. And It is cost...
# 816     I've been buying this on n off for months n al...
# 817     A lot better than wet roll on and spray deodorant
# 818                lovely, similar to the luxurious scent
# 819          Actually works, but it does streak a little.
# 820     It is rich and taste. Very beef. Love putting ...
# 821     Tastes of nothing. Such a shame. He used to bu...
# 822     His face wash left my face feeling really clea...
# 823     His is a really great product and I2019m very ...
# 824     I love simple products, I have combination ski...
# 825     I love this face wash! Like all simple product...
# 826     It2019s fine, it does exactly what it says on ...
# ...
# 1443    Our household normally use comfort, however I ...
# 1444                                               Lovely
# 1445    His listing is for a pack of 8, concentrated f...
# 1446    my kiss will not spend a whole week without No...
# 1447    His is a lovely scent of fresh flowers (Russia...
# 1448    Shop bought is much more expensive than l paid...
# 1449    Very very efficient !!!! In effective and nice...
# 1450    Of I was a wild-eyed enthusiast and was asked ...
# 1451    I have used this softened forever, but why has...
# 1452    They say its lumen free, i used one in a beef ...
# 1453    this was one of the first cream handwash##coul...
# 1454    I use this product all over, face included. Ta...
# 1455    I bought this for the first time a couple of w...
# 1456    Why have they changed the colour and perfume o...
# 1457    I buy ve stock tubes in big patches but this w...
# 1458              Great shampoo, used for washing my hair
# 1459    Incredible service & a bargain price. Thank-yo...
# 1460    His pack of 8 bottles of sundry conditioned is...
# 1461    You know what you are going to get with Comfor...
# 1462    I really like this - the scent is not overpowe...
# 1463    His is a good bundle, the products are really ...
# 1464    I have used this for washing both our clothing...
# 1465                                     Good bulk price.
# 1466                                                 Good
# 1467    my son loved the product and would recommend e...
# 1468                                   highly recommended
# 1469                                                 good
# 1470    Because the bottles are smaller and lighter, a...
# 1471                              Amazing value for money
# 1472        Did not disappoint. A little goes a long way.
# 1473                                                    K
# 1474    I've used this conditioned before and the smel...
# 1475    Such cheaper than in the shops. His works real...
# 1476         Great product and great price will buy again
# 1477                                        Great Value !
# 1478    His is a great size to keep close at hand as i...
# 1479    These are 540ml bottles giving 36 wash loads o...
# 1480    I got this on a deal for Â£9- amazing value fo...
# 1481                                    Not too impressed
# 1482    Fantastic value with a lovely scent I will be ...
# 1483    Clearly this latest product variation from Com...
# 1484    I usually use secret, which is the best by a c...
# 1485                        Another on the bathroom shelf
# 1486                                                Value
# 1487    Great convenient product much easier that powd...
# 1488    His is a great offer works out Â£5 a bag of 38...
# 1489    I bought this thinking I got it for bargain fo...
# 1490    The outer layer covering the liquid becomes a ...
# 1491                                                 Vice
# 1492                  getting a non big in 1, great value
# 1493                                Great value for money
# 1494    Great price for the number of wishes you get. ...
# 1495    Excellent item, we use this all the time, grea...
# 1496    Superb kit. The peril non-big is great and we ...
# 1497                  Brilliant product love Persia in 1.
# 1498    I did a large amount of sundry yesterday and w...
# 1499    Great value for money - washing smells lovely ...
# 1500                                       Love the smell
# 1501                                                 Good
# 1502    Good price and no carrying heavy items home fr...
# 1503                             Great item bargain price
# 1504    Excellent value for money, lasts long and bett...
# 1505    Great value for money would buy again. Use it ...
# 1506    Cab deal of the day my go to deodorant and it...
# 1507                                   Washing my clothes
# 1508    By mistake but these were the little bottles s...
# 1509                                           Good price
# 1510    Very happy with this order arriving same day a...
# 1511    It's great that a lot of effort has been made ...
# 1512                                        Great product
# 1513    His fabric conditioned not only leaves your cl...
# 1514    Leaves nice smell on my clothes and feeling soft.
# 1515                                          Great value
# 1516    Of you have storage, always better to buy bigg...
# 1517    I have used this brand forever and love the wa...
# 1518    I order these every month. theyre good value ...
# 1519                                 Well worth the money
# 1520                           Great smell & just the job
# 1521    I was asked if ofd like to review Comfort Int...
# 1522         His shampoo is the best.That a bargain also.
# 1523    I love the smell of this deodorant even though...
# 1524                                            Very good
# 1525    Love the smell of this. my washing smells lush...
# 1526                  Like the flavour Used it for eating
# 1527                 Good value for money would buy again
# 1528                                                 Good
# 1529    Light scent. Keeps going for 48 hours. Doesn't...
# 1530    Will take months before you can finish it. Ver...
# 1531                                Vice smell to clothes
# 1532    Smells so fresh, and not overpowering. Bandy t...
# 1533    It seems like a good deal but I used a whole b...
# 1534        Wonderful scent! Keeps me feel fresh all day.
# 1535                                         Long lasting
# 1536          In excellent product which works amazingly.
# 1537    andt complain its my favourite! Smells so go...
# 1538                                               Hunger
# 1539    Ultra concentrate so you don't have to use as ...
# 1540    I am in love with this softened so when I foun...
# 1541    The smell is so nice and always wakes me up in...
# 1542                                              Love it
# 1543                                       Must EXCELLENT
# 1544          Convenient . Smells great . Soft and fluffy
# 1545                   let me know when back on offer pus
# 1546    To cheap when I purchased in bulk. Smell fanta...
# 1547                     Value for money and smell lovely
# 1548    That else can I say? His was fantastic value f...
# 1549    Lovely smell. Only need to use half a cap of t...
# 1550    His set of sensitive washing soap is perfectly...
# 1551    The hope attached to the scent of fabric condi...
# 1552    Smells gorgeous even if ofve dried them in th...
# 1553    These are gentle, skin-kind versions within th...
# 1554                                 good buy smells lush
# 1555    I used Peril non-big for many years, but chang...
# 1556    I regularly use Comfort intense conditioned - ...
# 1557    Although biological detergents are generally m...
# 1558    His sundry set is excellent value. I like the ...
# 1559                      Great money saving subscription
# 1560    It the current price, this works out at about ...
# 1561    Bulk buying this Intense version of this seems...
# 1562    Easy and convenient to use, leaving sundry fre...
# 1563    Average and not as good as L'real but half the...
# 1564    inm not sure it lives up to all the hope that...
# 1565    By big baby is 32 but still has really sensiti...
# 1566    His is one of my favourite but always feel lik...
# 1567    Traditional comfort in a lovely fresh fragranc...
# 1568                                         Great thanks
# 1569                       Always use this for my washing
# 1570    Clearly this latest product variation from Com...
# 1571                                                 good
# 1572             Great value for money. Love this product
# 1573    Love this stuff, long lasting smell and gentle...
# 1574    Three pack or lynn shower get. Recent large size.
# 1575    Been eating Partite for nearly 70 years and al...
# 1576    To nice and such a bargain. Takes my hair smel...
# 1577    Comfort has always been my go to brand for fab...
# 1578                                         Good product
# 1579    His is for 8 x 540 my of Comfort Intense Sundr...
# 1580                                                 good
# 1581                                            thank you
# 1582                                           good price
# 1583                                          Is expected
# 1584                                     Received damaged
# 1585    His has got to be face. tos thin and see thro...
# 1586    I was a bit worried that a product called 'Int...
# 1587    His is my rd time ordering this shampoo. It sm...
# 1588    Currently selling at a price comparable to tha...
# 1589    I barely get 30 wishes out if this. Not value ...
# 1590    Although the bottle is only 540 my, the condit...
# 1591                                         Good quality
# 1592    I have been sent the fig pop nodules instead o...
# 1593                     keeps me dry and smells good too
# 1594                                           GOOD PRICE
# 1595                                          Great value
# 1596    Love the smell ..not too overpowering. Lasts w...
# 1597                                            I love it
# 1598    I've not used a separate conditioned in years,...
# 1599                                           Works well
# 1600                         Great value plenty of wishes
# 1601    His is a more traditional scent from fabric co...
# 1602    Comfort Intense has a nice fresh fragrance, al...
# 1603    I love this product. It retains the quality on...
# 1604    His is a multi-pack of eight bottles of fabric...
# 1605    All my family have sensitive skin and perfume ...
# 1606                                                 Good
# 1607                Great quality and super fast delivery
# 1608    I'm used to using the standard Comfort fabric ...
# 1609    Does what it's supposed to while smelling fres...
# 1610                                          Great smell
# 1611                                           Good Value
# 1612    Gorgeous smell & fabulous value! Only thing is...
# 1613    His is a good bundle, the conditioned is reall...
# 1614    Some arrived with cuts in the lids so had to b...
# 1615           Brilliant offer and such a gorgeous smell.
# 1616                           Lovely product bargain buy
# 1617                                       Great on money
# 1618    LIKES - Lots of softness. The washed clothing ...
# 1619               Is that clean, or is that CLEAN. Vice.
# 1620                                        love this one
# 1621    I purchased these on offer however, I was kind...
# 1622                            Good purchase & delivery.
# 1623    Great price, excellent value. Wish they did th...
# 1624    Round that after using two bottles found that ...
# 1625    He use Person non-big washing liquid all the t...
# 1626    I have bought this product before and liked it...
# 1627    His is THE best night cream I have ever used. ...
# 1628    I love this product; Ve been using it for a lo...
# 1629    I love this product it is part of my essential...
# 1630    I love this scrub, as you actually feel as tho...
# 1631    I have been using this deodorant for 2 months ...
# 1632    I like it a lot, it's kind to my skin, I use i...
# 1633    Must love random have to have them , crazy as ...
# 1634    Brought this years ago and loved it then when ...
# 1635    Vaseline is one of those products that has so ...
# 1636    Great exfoliation properties, but fluff ends u...
# 1637    I bought this recently, love the smell of it &...
# 1638    Oh i can say i use it everyday for all part of...
# 1639    I love Vaseline. Now the how soft my skin feel...
# 1640    I have ironically dry lips- think flay and dry...
# 1641    Always great... it is very versatile.. I use i...
# 1642    amazing!can rate it enough got it as a gift an...
# 1643    i used to use this all the time however since ...
# 1644    I tried this shampoo as I have always used L'r...
# 1645    amazing!can rate it enough got it as a gift an...
# 1646    Luxurious cream and a lovely smell which gave ...
# 1647    Not impressed with this fanning lotion it is t...
# 1648    Great exfoliation properties, but fluff ends u...
# 1649    ofve been drinking this tea for a long time. ...
# 1650    Ought this as my friend uses it and love the s...
# 1651    One of the best shower soap I have ever used w...
# 1652    By all time favourite softened ofve never sme...
# 1653    I buy ve stock tubes in big patches but this w...
# 1654    I love these and have used them for years now....
# 1655    His is one my favourite scent however ofve re...
# 1656    I normally buy peril colour powder, but as it ...
# 1657    I have used this softened forever, but why has...
# 1658    great ever ,always I by this soup ... best tha...
# 1659    Since I discovered this smell I have never cha...
# 1660    Bring by the surf gems they were so good and v...
# 1661    By wife loves a good shower get and this is th...
# 1662                                Ought for my daughter
# 1663    It feels like it was diluted. People who prefe...
# 1664    I use this a lot, it's really good and surpris...
# 1665                                                 Good
# 1666    Does what it says, protects my hair when i blo...
# 1667    North the money excellent product and well pac...
# 1668                                    Really good price
# 1669    By fine and a little over processes hair has l...
# 1670    Oddly enough I felt like it unlocked gradually...
# 1671     Really good size and makes my clothes smell nice
# 1672                                      EXCELLENT VALUE
# 1673                               Vice does what it says
# 1674                                         Smells great
# 1675                          Spells nice cleaner is good
# 1676                                                Great
# 1677                 Last a year in a 10 pack great value
# 1678    Smells nice for the 5 minutes it works for. I ...
# 1679                                        Smells lovely
# 1680    Added to a recent Amazon Pantry order as a ver...
# 1681           Well loved by whole family hence purchase.
# 1682    Wouldn't normally complain but it looks like s...
# 1683            I love this product its great for my hair
# 1684       Love this stuff- it literally clean anything!!
# 1685    Ought with a prime food package so just as goo...
# 1686    The pack is good but l've not actually consume...
# 1687                              Shines as well as clean
# 1688                            Would not wash without it
# 1689                   Smells really nice would buy again
# 1690                                         Is described
# 1691    Vice scent, large bottle which seems to be las...
# 1692                                        Great product
# 1693                       Did what it said on the bottle
# 1694        I always use this one and the price was great
# 1695    There might be some more suitable for sensitiv...
# 1696                                         Good Product
# 1697                                    Family likes them
# 1698    I use this spray every time I dry my hair. It ...
# 1699    Pleasing aroma after wandering clothes act Val...
# 1700                                          Haste fine.
# 1701    These melted easily into the sauce but was ove...
# 1702    I was disappointed with these. The size seemed...
# 1703    It would be good to point out that If does tes...
# 1704    Will quite happily buy these instead of the us...
# 1705    Myself and my grandchildren love these allies....
# 1706    Its been a while since I had the real thing an...
# 1707    Love this shower get, great for sensitive skin...
# 1708    Am a Coeliac and intolerant to cows milk, and ...
# 1709    Very disappointed in these capsules. The previ...
# 1710    I find these wiped get my make up off easily a...
# 1711    Great taste, lumen free & began with no palm o...
# 1712    I was so excited to purchase this as I react t...
# 1713    These are amazing, just like the original Corn...
# 1714    Our whole family loves boris and we use it dai...
# 1715    Contents of this bottle is lovely. HOWEVER try...
# 1716    These taste great and you cannot Want tell the...
# 1717    Really pleased to have began Cornettos at last...
# Name: review_text, dtype: object

# %%
#REMOVING THE STOPWORDS,PUNCTUATIONS, LOWERCASING, AND STEMMING OF THE SENTENCES
def text_preprocessing(text):
    removed_special_characters = re.sub("[^a-zA-Z]", " ", str(text))
    tokens = removed_special_characters.lower().split()
    
    stemmer = PorterStemmer()
    cleaned = []
    stemmed = []
    
    for token in tokens:
        if token not in sw:
            cleaned.append(token)
            
    for token in cleaned:
        token = stemmer.stem(token)
        stemmed.append(token)

    return " ".join(stemmed)

# %%
df['review_text'] = df['review_text'].apply(text_preprocessing)

# %%
df['review_text'].head()
# Out:
# 0    get older know like suitabl bodi like dove pro...
# 1    three gigant marmit jar last probabl whole lif...
# 2                                                excel
# 3                          great flavour top slow cook
# 4                                                  say
# Name: review_text, dtype: object

# %%
#CHECK RARE WORDS
r = pd.Series(' '.join(df['review_text']).split()).value_counts()[-10:]
print("RARE WORDS:")
print(r)
# Out:
# RARE WORDS:
# accident     1
# chuck        1
# emigr        1
# salt         1
# mushroom     1
# fli          1
# cult         1
# revitalis    1
# advantag     1
# tendon       1
# dtype: int64

# %%
#CHECK TOP COMMON WORDS
words = '' 
for i in df["review_text"]: 
    tokens = i.split()   
    words += " ".join(tokens)+" "

    
word_cloud = WordCloud(width = 700, height = 700, 
                       background_color ='white', 
                       min_font_size = 10).generate(words) 
plt.figure(figsize = (5, 5)) 
plt.imshow(word_cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
#removing common and rare words
common = pd.Series(' '.join(df['review_text']).split()).value_counts()[:3]
common = list(common.index)
df['review_text'] = df['review_text'].apply(lambda i: " ".join(i for i in i.split() if i not in common))

rare = pd.Series(' '.join(df['review_text']).split()).value_counts()[-3:]
rare = list(rare.index)
df['review_text'] = df['review_text'].apply(lambda i: " ".join(i for i in i.split() if i not in rare))

# %%
#WORDCLOUD - UPDATED TOP WORDS
words = '' 
for i in df["review_text"]: 
    tokens = i.split()   
    words += " ".join(tokens)+" "

    
word_cloud = WordCloud(width = 700, height = 700, background_color ='white', min_font_size = 10).generate(words) 
plt.figure(figsize = (5, 5)) 
plt.imshow(word_cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# - After removing the top 3 common word (it was removed since it would remove its meaning from the entire thing), we are left with the current top 10 words. As seen from above, we can see that the sentiment of it is quite positive, meaning that this dataset is dealing with many positive-centric reviews. The general polarity is thus, positive, and needs to be kept in mind for analysis later. It is to be noted that due to the lack of negative reviews in this case can cause for there to be discrepencies when, for instance a negative value is set to be identified as "fake" or "real", and thus can be added as a limitation to this study.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nikhi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df['review_text'].apply(word_tokenize).head()
# Out:
# 0    [get, older, know, like, suitabl, bodi, like, ...
# 1    [three, gigant, marmit, jar, last, probabl, wh...
# 2                                              [excel]
# 3                    [great, flavour, top, slow, cook]
# 4                                                [say]
# Name: review_text, dtype: object

# %%
#SAVING UPDATED DATAFRAME AS .csv FILE
df.to_csv('Data/cleaned_data.csv')
